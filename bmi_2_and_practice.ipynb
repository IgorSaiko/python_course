# %%
#-----BMI 2.0
dict1 = { "name": input('введите имя: '),  "age": int(input('введите возраст: ')), "gender": input('введите ваш пол (ответ: м/ж): '), "growth": int(input("Введите Ваш рост (в сантиметрах):")), "weight": int(input("Введите Ваш вес (в килограммах):")) }

x = int( dict1["weight"] / ((dict1["growth"]/100)**2))
scale = '20' + "=" * (x - 20)  + str("|") + "="*(50 - x) + "50"

if dict1["gender"] == 'м':
    men = 'мужчин'
    dict1["gender"] = men
else:
    dict1["gender"] == 'ж'
    woman = 'девушек'
    dict1["gender"] = woman
    #------------------------------------------------#
print("Ваш индекс массы тела:", x )

if x <= 18.5 and x < 24.9:
    print( dict1["name"], 'поздравляем , при весе',  dict1["weight"], 'в возасте', dict1["age"], 'у вас нормальный вес тела')
elif x >= 25 and x <= 30:
    print(dict1["name"], 'ваш индекс выше положенного, советуем поменять образ жизни на более активный' )
elif x >= 30 and x <=34.9:
    print(dict1["name"], 'при росте в', dict1["growth"], 'и весе', dict1["weight"], 'у вас Ожирение (Класс I)', 'для', dict1["gender"], 'в возрасте', dict1["age"], 'лет, это повод обратиться к своему врачу или диетологу')
elif x >=35 and x <= 40:
    print(dict1["name"], 'при росте в', dict1["growth"], 'и весе', dict1["weight"], 'у вас Ожирение (Класс II - тяжелое)', 'для', dict1["gender"], 'в возрасте', dict1["age"], 'то тяжелая форма ожирения, обратитесь в срочном порядке к хирургу')
elif x >=40: 
    print(dict1["name"], 'у вас Ожирение (Класс III - крайне тяжелое), ваша жизнь в опасности, срочно обратитесь к врачам')
        
print(scale)
print('имя:', dict1["name"], 'возраст:', dict1["age"], 'пол:',  dict1["gender"], 'рост:', dict1["growth"], 'вес:', dict1["weight"]    )
# Out:
# введите имя: igor
# введите возраст: 24
# введите ваш пол (ответ: м/ж): м
# Введите Ваш рост (в сантиметрах):180
# Введите Ваш вес (в килограммах):87
# Ваш индекс массы тела: 26
# igor ваш индекс выше положенного, советуем поменять образ жизни на более активный
# 20======|========================50
# имя: igor возраст: 24 пол: мужчин рост: 180 вес: 87

# %%
# Вывести на экран 0, не если нет ни одного нуля - вывести: "Нет нулевых значений!!!" (без if)
a = int(input('введите число а '))
b = int(input('введите число b '))
c = int(input('введите число c '))

while a == 0 or b == 0 or c == 0:
    print("0")
    break
else:
    print("Нет нулевых значений!!!")

#Вывести первое ненулевое значение,но если введены все нули - вывести "Введены все нули!" (без if)
while a == 0 and b == 0 and c == 0:
    print("Введены все нули!")
    break
else:
    print(a)
    
#Если первое значение больше чем сумма второго и третьего вывести a - b - c (п3 и п4 проверить одним условием(конструкцией)
#Если первое значение меньше или равно сумме второго и третьего вывести b + c - a

if a > b + c:
    print('a - b - c')
else: 
    a <= b + c
    print('b + c - a')
    
#Если первое значение больше чем сумма второго и третьего вывести a - b - c (п3 и п4 проверить одним условием(конструкцией)
#Если первое значение меньше или равно сумме второго и третьего вывести b + c - a
if a > b + c:
    print('a - b - c')
else: 
    a <= b + c
    print('b + c - a')
    
#Если первое значение больше 50 и при этом одно из оставшихся значение больше первого вывести "Вася" (проверить одним условием)
if a > 50 and b > a and c > a:
    print("Вася")
else:
    print('первое значение не больше 50 и при этом одно из оставшихся значений не больше первого') 
    
#Если первое значение больше 5 или оба из оставшихся значений равны 7 вывести "Петя"(проверить одним условием)
if a> 5 or b == 7 or c == 7:
    print("Петя") 
else:
    print('первое значение не больше 5 и оба из оставшихся значений не равны 7')
# Out:
# введите число а 43
# введите число b 32
# введите число c 21
# Нет нулевых значений!!!
# 43
# b + c - a
# b + c - a
# первое значение не больше 50 и при этом одно из оставшихся значений не больше первого
# Петя
